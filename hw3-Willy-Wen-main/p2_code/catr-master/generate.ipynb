# %%
import torch
from torch.utils.data import Dataset, DataLoader
from tokenizers import Tokenizer
from torchvision import models, datasets, transforms

import numpy as np
import time
import sys
import os
import json
import tqdm
from PIL import Image

from models import utils, caption
from configuration import Config

# %%
MAX_DIM = 224
config = Config()

class p2Data(Dataset):
    def __init__(self, fnames, transform=None):
        self.transform = transform
        self.fnames = fnames
        self.file_list = [file for file in os.listdir(fnames) if file.endswith('.jpg')]
        self.file_list.sort()
        self.num_samples = len(self.file_list)

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        fname = self.file_list[idx]
        filepath = os.path.join(self.fnames, fname)
        img = Image.open(filepath)
        img = self.transform(img)
        return img, fname
    
class to_dim:
    def __init__(self):
        self.dim = 3

    def __call__(self, x):
        if x.shape[0] == 1:
            x = x.repeat(3,1,1)
        return x

def create_caption_and_mask(start_token, max_length):
    caption_template = torch.zeros((imgs.shape[0], max_length), dtype=torch.long)
    # print('caption_template = ', caption_template)
    mask_template = torch.ones((imgs.shape[0], max_length), dtype=torch.bool)
    # print('mask_template = ', mask_template)
    caption_template[:, 0] = start_token
    mask_template[:, 0] = False

    return caption_template, mask_template

# %%
test_transform = transforms.Compose([
    transforms.ToTensor(),
    to_dim(),    
    transforms.Resize((MAX_DIM, MAX_DIM)),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
test_image_dir = 'D:/NTU/DLCV/hw3/hw3_data/p2_data/images/val'
test_set = p2Data(test_image_dir, transform=test_transform)
test_dataloader = DataLoader(test_set, batch_size=32, shuffle=False)
device = torch.device(config.device)
print(f'Initializing Device: {device}')
# Out:
# Initializing Device: cuda

# %%
seed = config.seed + utils.get_rank()
torch.manual_seed(seed)
np.random.seed(seed)

# %%
model, criterion = caption.build_model(config)
model.to(device)
model.eval()
# Out:
# D:\env\dlcv_env\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# D:\env\dlcv_env\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Caption(
#   (backbone): Joiner(
#     (0): Backbone(
#       (body): IntermediateLayerGetter(
#         (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#         (bn1): FrozenBatchNorm2d()
#         (relu): ReLU(inplace=True)
#         (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (layer1): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (layer2): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (3): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (layer3): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (3): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (4): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (5): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (6): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (7): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (8): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (9): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (10): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (11): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (12): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (13): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (14): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (15): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (16): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (17): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (18): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (19): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (20): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (21): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (22): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (layer4): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (1): PositionEmbeddingSine()
#   )
#   (input_proj): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#   (transformer): Transformer(
#     (encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#         (1): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#         (2): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#         (3): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#         (4): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#         (5): TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (embeddings): DecoderEmbeddings(
#       (word_embeddings): Embedding(30522, 256, padding_idx=0)
#       (position_embeddings): Embedding(128, 256)
#       (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (decoder): TransformerDecoder(
#       (layers): ModuleList(
#         (0): TransformerDecoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (multihead_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#           (dropout3): Dropout(p=0.1, inplace=False)
#         )
#         (1): TransformerDecoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (multihead_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#           (dropout3): Dropout(p=0.1, inplace=False)
#         )
#         (2): TransformerDecoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (multihead_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#           (dropout3): Dropout(p=0.1, inplace=False)
#         )
#         (3): TransformerDecoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (multihead_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#           (dropout3): Dropout(p=0.1, inplace=False)
#         )
#         (4): TransformerDecoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (multihead_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#           (dropout3): Dropout(p=0.1, inplace=False)
#         )
#         (5): TransformerDecoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (multihead_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#           (dropout3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (mlp): MLP(
#     (layers): ModuleList(
#       (0): Linear(in_features=256, out_features=512, bias=True)
#       (1): Linear(in_features=512, out_features=512, bias=True)
#       (2): Linear(in_features=512, out_features=30522, bias=True)
#     )
#   )
# )

# %%
config.checkpoint
# Out:
# './checkpoint.pth'

# %%
if os.path.exists(config.checkpoint):
    print("Loading Checkpoint...")
    # checkpoint = torch.load(config.checkpoint, map_location='cpu')
    checkpoint = torch.load(config.checkpoint)
    model.load_state_dict(checkpoint['model'])
# Out:
# Loading Checkpoint...

# %%
print(f"Valid: {len(test_set)}")
# Out:
# Valid: 1789

# %%
tokenizer = Tokenizer.from_file("D:/NTU/DLCV/hw3/hw3_data/caption_tokenizer.json")
total = len(test_dataloader)

# %%
start_token = 2
end_token = 3

# %%
max_len = 60
result_dict = {}
with tqdm.tqdm(total=total) as pbar:
    with torch.no_grad():
        for k, (imgs, fnames) in enumerate(test_dataloader):
            imgs = imgs.to(device)
    #         print(imgs.shape)

            cap, cap_mask = create_caption_and_mask(start_token, config.max_position_embeddings)
            cap = cap.to(device)
            cap_mask = cap_mask.to(device)
    #         print(cap.shape)

            for i in range(max_len):
                predictions = model(imgs, cap, cap_mask)[:, i, :]
                predicted_id = torch.argmax(predictions, axis=-1)
                for j in range(imgs.shape[0]):
                    if predicted_id[j] != 3:
                        cap[j, i + 1] = predicted_id[j]
                        cap_mask[j, i + 1] = False

            for r in range(imgs.shape[0]):
                s = tokenizer.decode(cap[r].tolist(), skip_special_tokens=True).capitalize().split('.')[0]
                s = s[:-1]+'.'
                name = fnames[r][:-4]
                print(f'{name}: {s}')
                result_dict[name] = s
            pbar.update(1)
# Out:
#   0%|                                                                                           | 0/56 [00:00<?, ?it/s]D:\NTU\DLCV\hw3\catr-master\models\position_encoding.py:38: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature ** (2 * (dim_t // 2) / self.num_pos_feats)
#   2%|█▍                                                                                 | 1/56 [00:23<21:32, 23.50s/it]
# 000000000368: A group of people playing frisbee in a field.
# 000000000620: A plate with a sandwich and a fork and a fork.
# 000000001548: A man is standing on a surfboard in the water.
# 000000001999: A cat is sitting on a bed with a blanket.
# 000000002982: A train is on a track near a train station.
# 000000003461: A man and a woman are walking down a sidewalk.
# 000000003771: A sheep is eating grass in a field.
# 000000003999: A cat is laying on a bed in a room.
# 000000004956: An elephant is standing in the grass with a tree in the background.
# 000000005418: A group of giraffes standing in a field.
# 000000005434: A dog is sitting on a bench in front of a fence.
# 000000005757: A train is parked on the side of a road.
# 000000005811: A red and white bus is parked on the side of the road.
# 000000006393: A man in a black shirt and a black shirt is standing on a toilet.
# 000000006789: A large boat is parked on the side of a road.
# 000000007201: A red and white photo of a red fire hydrant.
# 000000008320: A group of zebras standing in a fenced in area.
# 000000009214: A zebra standing in a field of grass with trees in the background.
# 000000009813: A horse is pulling a cart with a dog.
# 000000010217: A plate with a sandwich and a knife on it.
# 000000010496: A man flying a kite in a field.
# 000000011182: A man is walking down the street with a dog.
# 000000011323: A red umbrella is sitting on a rock in the woods.
# 000000011613: A group of people standing on a snow covered slope.
# 000000012103: A bathroom with a toilet and a sink.
# 000000013169: A person holding a piece of pizza on top of a plate.
# 000000013414: A parking meter with a sign on the side of it.
# 000000013506: A baseball player is swinging a bat on a field.
# 000000013844: A man in a suit and tie is holding a tie.
# 000000013938: A herd of elephants standing in a field of grass.
# 000000014475: A stuffed bear is sitting on a table.
# 000000014726: A man is standing in front of a bus.
#   2%|█▍                                                                                 | 1/56 [00:28<25:56, 28.30s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [12], line 18
#      16 predicted_id = torch.argmax(predictions, axis=-1)
#      17 for j in range(imgs.shape[0]):
# ---> 18     if predicted_id[j] != 3:
#      19         cap[j, i + 1] = predicted_id[j]
#      20         cap_mask[j, i + 1] = False
#
# KeyboardInterrupt:

# %%
json_object = json.dumps(result_dict, indent=4)
with open("p2_output.json", "w") as outfile:
    outfile.write(json_object)

# %%
result_dict
# Out:
# {'000000000368': 'A man is playing frisbee in a field.',
#  '000000000620': 'A man in a white shirt is standing in front of a building.',
#  '000000001548': 'A man riding a wave on a surfboard in the snow.',
#  '000000001999': 'A cat is sitting on a wooden bench.',
#  '000000002982': 'A large clock tower with a clock on it.',
#  '000000003461': 'A man is riding a skateboard on a street.',
#  '000000003771': 'A dog is running in the grass.',
#  '000000003999': 'A cat sitting on top of a wooden table.',
#  '000000004956': 'A black dog is standing on a rock.',
#  '000000005418': 'A giraffe standing in a field with a tree in the background.',
#  '000000005434': 'A large clock on a pole in a room.',
#  '000000005757': 'A train is parked on the tracks in front of a building.',
#  '000000005811': 'A red bus is parked on the side of a street.',
#  '000000006393': 'A bathroom with a toilet and a toilet with a toilet.',
#  '000000006789': 'A large plane is on a runway in the water.',
#  '000000007201': 'A man is riding a wave on a surfboard.',
#  '000000008320': 'A man and woman are standing in front of a lake.',
#  '000000009214': 'A zebra is standing in the grass near a tree.',
#  '000000009813': 'A man in a black shirt is standing in front of a tree.',
#  '000000010217': 'A plate of food and a fork on a table.',
#  '000000010496': 'A large airplane is on a runway in the water.',
#  '000000011182': 'A train is on a track near a forest.',
#  '000000011323': 'A red fire hydrant sitting on top of a sidewalk.',
#  '000000011613': 'A group of people skiing down a snow covered slope.',
#  '000000012103': 'A bathroom with a toilet and a sink sink.',
#  '000000013169': 'A plate of food with a fork and knife.',
#  '000000013414': 'A man is standing on a sidewalk with a dog.',
#  '000000013506': 'A baseball player is swinging a bat at a ball.',
#  '000000013844': 'A large bathroom with a toilet and a sink.',
#  '000000013938': 'A man is riding a horse on a dirt road.',
#  '000000014475': 'A cat laying on top of a wooden table.',
#  '000000014726': 'A red and white bus is parked in front of a building.',
#  '000000014941': 'A woman is eating a pizza on a table.',
#  '000000014985': 'A group of people standing in front of a building.',
#  '000000015733': 'A man riding a wave on a surfboard in the ocean.',
#  '000000015797': 'A man riding a wave on a snowboard.',
#  '000000015984': 'A dog is running in the grass.',
#  '000000016520': 'A dog is running in the grass.',
#  '000000017167': 'A man in a black shirt is riding a skateboard.',
#  '000000018183': 'A bathroom with a toilet and a sink sink.',
#  '000000018467': 'A plate of food with a salad and a fork.',
#  '000000019491': 'A woman is eating a slice of pizza.',
#  '000000019754': 'A man in a red shirt is jumping in the air.',
#  '000000019797': 'A man is riding a skateboard on a ramp.',
#  '000000020147': 'A giraffe standing in a field with a tree in the background.',
#  '000000020172': 'A man is standing on a sidewalk with a large blue umbrella.',
#  '000000020972': 'A white polar bear is standing on a beach.',
#  '000000021374': 'A red fire hydrant sitting on the side of a road.',
#  '000000022051': 'A group of people standing on top of a beach.',
#  '000000022198': 'A woman in a red shirt is holding a baseball bat.',
#  '000000022440': 'A red and white bus is parked on the side of a street.',
#  '000000022478': 'A cat is sitting on top of a bed.',
#  '000000022979': 'A red bus is parked on the side of a street.',
#  '000000023051': 'A red and white bus is parked in front of a building.',
#  '000000023603': 'A man in a blue shirt is playing frisbee.',
#  '000000024100': 'A man is standing on a beach with a kite.',
#  '000000024454': 'A man riding a wave on a surfboard in the ocean.',
#  '000000025353': 'A man is standing on a snow covered slope.',
#  '000000025516': 'A person is skiing down a snowy hill.',
#  '000000026162': 'A red fire hydrant sitting on a sidewalk next to a fire hydrant.',
#  '000000026294': 'A pizza with a fork and a fork on top of it.',
#  '000000026501': 'A man is standing on a snowy mountain.',
#  '000000027675': 'A red and white train is on a track.',
#  '000000028523': 'A man is riding a horse on a dirt road.',
#  '000000028674': 'A man in a blue shirt is holding a plate of food.',
#  '000000029160': 'A surfer is riding a wave on a wave.',
#  '000000030151': 'A man in a blue shirt is holding a cell phone.',
#  '000000030403': 'A man in a blue shirt is riding a skateboard.',
#  '000000030518': 'A bathroom with a toilet and a sink in the corner.',
#  '000000030731': 'A large airplane flying over a large body of water.',
#  '000000030791': 'A cat sitting on top of a wooden table.',
#  '000000031073': 'A person flying a kite in the air.',
#  '000000031504': 'A man in a black shirt is holding a cell phone.',
#  '000000031578': 'A man in a black shirt is riding a horse.',
#  '000000031865': 'A cat sitting on top of a laptop computer.',
#  '000000032176': 'A bird perched on a branch in a tree.',
#  '000000032566': 'A group of elephants walking in a river.',
#  '000000032909': 'A man is standing on a skateboard in the water.',
#  '000000032960': 'A red and white train is on a track.',
#  '000000033717': 'A train is on a train track near a forest.',
#  '000000033721': 'A man is standing next to a tree.',
#  '000000033798': 'A kitchen with a sink and a sink.',
#  '000000033938': 'A man is riding a skateboard on a ramp.',
#  '000000033991': 'A woman in a red shirt is holding a baseball bat.',
#  '000000033995': 'A plate of food with a fork and a fork.',
#  '000000034708': 'A man in a white shirt is playing a guitar with a woman.',
#  '000000034938': 'A kitchen with a sink and a sink.',
#  '000000034973': 'A red fire hydrant sitting in a parking lot.',
#  '000000035101': 'A fire hydrant is sitting on the side of a road.',
#  '000000035712': 'A bird is sitting on a rock with a red in its mouth.',
#  '000000036508': 'A plate of food with a fork and a fork.',
#  '000000038053': 'A large bird is sitting on a rock.',
#  '000000038064': 'A giraffe standing next to a tree in a field.',
#  '000000038196': 'A bird is sitting on a rock in the grass.',
#  '000000038490': 'A large clock tower with a clock on top of it.',
#  '000000038722': 'A man in a white shirt is standing in front of a building.',
#  '000000038827': 'A bathroom with a toilet and a sink sink.',
#  '000000038892': 'A woman in a black shirt is holding a baby.',
#  '000000039540': 'A table with a sandwich and a drink on it.',
#  '000000040100': 'A man is standing next to a giraffe.',
#  '000000041413': 'A tennis player is holding a racket on a tennis court.',
#  '000000041796': 'A cat is sitting on a bed in a bathroom.',
#  '000000041962': 'A man in a red shirt is jumping in the air.',
#  '000000041997': 'A group of people standing on top of a beach.',
#  '000000042055': 'A red and white train is on a track.',
#  '000000042288': 'A man is standing on a beach holding a surfboard.',
#  '000000042818': 'A large airplane flying over a large body of water.',
#  '000000043404': 'A large clock tower with a clock on top of it.',
#  '000000044421': 'A woman in a black shirt and a tie is holding a plate of food.',
#  '000000045923': 'A red and white bus is parked on the side of a street.',
#  '000000046171': 'A cat laying on top of a bed.',
#  '000000046359': 'A large clock tower with a clock on top of it.',
#  '000000046813': 'A group of people standing in front of a building.',
#  '000000046883': 'A man is standing next to a tree.',
#  '000000046912': 'A train is on a track near a bridge.',
#  '000000047016': 'A bird flying in the sky on a beach.',
#  '000000047611': 'A large clock on a pole in a field.',
#  '000000047916': 'A young boy is playing with a frisbee in a field.',
#  '000000047940': 'A plate of food with a fork and a fork on it.',
#  '000000048474': 'A bird perched on a branch in a tree.',
#  '000000049017': 'A kitchen with a sink and a sink.',
#  '000000049068': 'A black dog is running in the dirt.',
#  '000000049234': 'A cat sitting on top of a chair next to a window.',
#  '000000049643': 'A man is riding a skateboard down a street.',
#  '000000049667': 'A large herd of sheep standing on a dirt road.',
#  '000000050034': 'A cat is laying on a bed in a room.',
#  '000000050470': 'A man in a blue shirt is playing tennis.',
#  '000000051339': 'A man is walking down the street.',
#  '000000051501': 'A man in a blue shirt is standing next to a giraffe.',
#  '000000051530': 'A man is standing next to a tree.',
#  '000000051862': 'A man is standing next to a car.',
#  '000000053015': 'A woman in a blue shirt is playing a guitar.',
#  '000000053232': 'A kitchen with a sink and a sink.',
#  '000000053640': 'A large airplane flying over a large body of water.',
#  '000000053665': 'A person riding a wave on a surfboard in the ocean.',
#  '000000053677': 'A man is riding a skateboard on a street.',
#  '000000053800': 'A man in a suit and tie is holding a cell phone.',
#  '000000054003': 'A man in a blue shirt is standing in front of a building.',
#  '000000054627': 'A group of giraffes standing in a field.',
#  '000000054870': 'A plate of food with a fork and a fork.',
#  '000000054924': 'A red fire hydrant sitting on a city street.',
#  '000000055033': 'A kitchen with a sink and a sink.',
#  '000000055389': 'A white dog laying on top of a bed.',
#  '000000056193': 'A train is on a track near a building.',
#  '000000056306': 'A man in a white shirt is standing next to a building.',
#  '000000056323': 'A red and white train is on a track.',
#  '000000056400': 'A man in a suit and tie is holding a cell phone.',
#  '000000056549': 'A train is on a track near a forest.',
#  '000000056699': 'A red fire hydrant sitting on the side of a street.',
#  '000000057883': 'A surfer riding a wave in the ocean.',
#  '000000057979': 'A plate of food on a table with a fork.',
#  '000000058965': 'A group of people playing frisbee on a field.',
#  '000000059267': 'A woman is eating a slice of cake.',
#  '000000060005': 'A group of people standing on a bench in front of a building.',
#  '000000060602': 'A group of people standing on top of a beach.',
#  '000000060812': 'A group of people standing on a bench.',
#  '000000062053': 'A man in a blue shirt is standing in front of a building.',
#  '000000062622': 'A man is riding a wave on a surfboard.',
#  '000000062824': 'A train is parked on the tracks in a rural area.',
#  '000000063182': 'A brown and white cow is standing in a field.',
#  '000000063330': 'A man is riding a skateboard on a street.',
#  '000000063434': 'A plate of food and a fork on a table.',
#  '000000063856': 'A large clock on a pole in front of a building.',
#  '000000064032': 'A man in a red shirt is standing in front of a building.',
#  '000000064036': 'A group of people playing frisbee on a field.',
#  '000000064149': 'A kitchen with a sink and a sink.',
#  '000000064389': 'A man in a black shirt and a black shirt is holding a plate of food.',
#  '000000065191': 'A man in a white shirt is standing next to a woman in a red shirt.',
#  '000000065357': 'A train is on a track near a forest.',
#  '000000066191': 'A baseball player is swinging a bat at a ball.',
#  '000000066516': 'A bathroom with a toilet and a sink.',
#  '000000068205': 'A woman in a black shirt and tie is playing a game.',
#  '000000068442': 'A kitchen with a sink and a sink.',
#  '000000068738': 'A computer keyboard and a laptop on a desk.',
#  '000000069266': 'A man in a blue shirt is standing in front of a building.',
#  '000000069320': 'A baseball player is swinging a bat at a ball.',
#  '000000069424': 'A large herd of sheep standing on a rock.',
#  '000000069501': 'A train is on the tracks in a rural area.',
#  '000000070240': 'A man in a black shirt is standing next to a woman in a red shirt.',
#  '000000071095': 'A man is playing frisbee on a field.',
#  '000000072396': 'A red and white train is on a track.',
#  '000000072794': 'A woman in a black shirt and tie is holding a cell phone.',
#  '000000073180': 'A man in a black shirt and a black shirt is holding a plate of food.',
#  '000000073981': 'A group of elephants walking in a field.',
#  '000000074001': 'A man in a white shirt is standing in front of a building.',
#  '000000074312': 'A giraffe standing in a grassy field next to a tree.',
#  '000000074411': 'A red and white train is traveling down the track.',
#  '000000075557': 'A man is riding a skateboard on a ramp.',
#  '000000076081': 'A man in a blue shirt is standing in front of a store.',
#  '000000077639': 'A man in a blue shirt is playing a guitar.',
#  '000000077667': 'A small clock on a pole in a room.',
#  '000000077750': 'A woman in a blue shirt is holding a plate of food.',
#  '000000078469': 'A man is riding a skateboard on a street.',
#  '000000079831': 'A woman is eating a sandwich on a table.',
#  '000000079836': 'A large airplane flying over a large body of water.',
#  '000000079924': 'A red fire hydrant sitting in a field.',
#  '000000081206': 'A large airplane is flying over a body of water.',
#  '000000081259': 'A train is parked on the tracks in front of a building.',
#  '000000081357': 'A woman in a blue shirt is holding a plate of food.',
#  '000000081675': 'A man is standing next to a car.',
#  '000000081784': 'A group of people standing on top of a beach with a kite.',
#  '000000081954': 'A group of elephants walking in a field.',
#  '000000081971': 'A man in a white shirt is playing a guitar with a man in a blue shirt.',
#  '000000082312': 'A group of people standing in front of a building.',
#  '000000082576': 'A large clock tower with a clock on top of it.',
#  '000000082740': 'A group of people standing on a bench.',
#  '000000083093': 'A man in a blue shirt is holding a cell phone.',
#  '000000083271': 'A dog is laying on a rock in the grass.',
#  '000000083601': 'A man in a black shirt is holding a tennis racket.',
#  '000000083873': 'A woman in a red shirt is holding a cell phone.',
#  '000000084123': 'A large clock tower with a clock on it.',
#  '000000084157': 'A cat is sitting on a bed in a room.',
#  '000000085852': 'A woman in a blue shirt is holding a baseball bat.',
#  '000000085960': 'A bathroom with a toilet and a sink.',
#  '000000087113': 'A clock tower with a clock on the top of it.',
#  '000000087483': 'A herd of elephants walking across a dirt road.',
#  '000000088176': 'A man in a black shirt is standing next to a dog.',
#  '000000088208': 'A man is flying a kite on a beach.',
#  '000000088377': 'A man is riding a motorcycle down a street.',
#  '000000089101': 'A dog is laying on a rock in the grass.',
#  '000000089253': 'A man in a black shirt is standing next to a woman in a red shirt.',
#  '000000090498': 'A bathroom with a toilet and a sink sink.',
#  '000000090628': 'A man riding a snowboard on a snow covered slope.',
#  '000000091604': 'A man in a blue shirt is playing frisbee.',
#  '000000091636': 'A group of people standing in front of a building.',
#  '000000091681': 'A man in a blue shirt is holding a cell phone.',
#  '000000091996': 'A man in a white shirt is standing in front of a window.',
#  '000000092338': 'A large airplane is on a runway in the water.',
#  '000000092342': 'A man in a blue shirt is holding a tennis racket.',
#  '000000092415': 'A man riding a wave on a surfboard.',
#  '000000092815': 'A man in a black shirt and a black shirt is holding a cell phone.',
#  '000000092910': 'A woman in a blue shirt is holding a plate of food.',
#  '000000093707': 'A train is parked on the tracks in front of a building.',
#  '000000094884': 'A large clock on a pole in a room.',
#  '000000095482': 'A large building with a clock on it is in the background.',
#  '000000096514': 'A bird is sitting on a rock formation.',
#  '000000096539': 'A man is standing in front of a window.',
#  '000000096643': 'A bathroom with a toilet and a sink.',
#  '000000097363': 'A group of people standing on a bench in front of a fence.',
#  '000000097568': 'A man is standing next to a truck.',
#  '000000098155': 'A man is standing next to a car.',
#  '000000098187': 'A man is riding a wave on a surfboard.',
#  '000000098268': 'A red fire hydrant sitting in a grassy area.',
#  '000000098322': 'A man in a red jacket is standing on a snow covered slope.',
#  '000000098830': 'A large group of people standing in front of a building.',
#  '000000099070': 'A man in a black shirt is standing next to a large tree.',
#  '000000099389': 'A red and white train is on a track.',
#  '000000099543': 'A man is standing on a skateboard in the snow.',
#  '000000099707': 'A man is standing on a sidewalk with a large blue umbrella.',
#  '000000099747': 'A large clock on a pole in a field.',
#  '000000100140': 'A man is standing in the water with a large blue sky.',
#  '000000100409': 'A man in a white shirt and a black shirt is standing in front of a building.',
#  '000000100667': 'A woman is eating a pizza on a table.',
#  '000000102445': 'A man is riding a horse on a dirt road.',
#  '000000102466': 'A large plane is on a runway in the water.',
#  '000000102996': 'A large elephant is standing in a field.',
#  '000000104410': 'A large clock tower with a clock on top of it.',
#  '000000104956': 'A woman in a blue shirt is playing with a frisbee.',
#  '000000105172': 'A brown and white cow is standing in a field.',
#  '000000105781': 'A red and white bus is parked on the street.',
#  '000000105904': 'A man is standing on a sidewalk with a large blue umbrella.',
#  '000000106096': 'A man in a black shirt is playing with a frisbee.',
#  '000000106144': 'A group of people sitting on a bench.',
#  '000000106206': 'A man in a red shirt is holding a tennis racket.',
#  '000000106688': 'A man in a blue shirt is standing on a sidewalk.',
#  '000000107511': 'A giraffe standing next to a tree in a field.',
#  '000000110617': 'A baseball player is swinging a bat at a ball.',
#  '000000110794': 'A large building with a clock on it is shown.',
#  '000000111121': 'A baseball player is swinging a bat at a ball.',
#  '000000111188': 'A cat laying on top of a wooden bench.',
#  '000000111277': 'A man in a blue shirt is playing frisbee.',
#  '000000111940': 'A man is walking down the street.',
#  '000000111944': 'A person is skiing down a snow covered slope.',
#  '000000112882': 'A kitchen with a sink and a sink.',
#  '000000113525': 'A train is parked on the tracks in front of a building.',
#  '000000113724': 'A man is standing next to a large blue building.',
#  '000000113757': 'A man in a white shirt is standing in front of a building.',
#  '000000113897': 'A bathroom with a toilet and a toilet with a toilet and a toilet.',
#  '000000114229': 'A man in a white shirt is playing a guitar with a man in a blue shirt.',
#  '000000114616': 'A bird is sitting on a rock in the water.',
#  '000000115636': 'A red and white train is on a track.',
#  '000000115642': 'A cat sitting on top of a laptop computer.',
#  '000000116557': 'A woman is eating a hot dog on a bed.',
#  '000000116633': 'A man is riding a skateboard on a snowy hill.',
#  '000000117201': 'A group of people skiing down a snow covered slope.',
#  '000000117691': 'A man is standing next to a tree.',
#  '000000118432': 'A large group of people standing on a beach.',
#  '000000121503': 'A train is on the tracks in a city.',
#  '000000121526': 'A man riding a wave on a surfboard in the ocean.',
#  '000000122440': 'A man is standing on a bench in the grass.',
#  '000000122586': 'A person on skis in the snow with a snowboard.',
#  '000000122597': 'A man in a blue shirt is holding a plate of food.',
#  '000000122934': 'A man in a blue shirt is standing on a sidewalk.',
#  '000000124132': 'A plate of food with a fork and a fork on it.',
#  '000000124210': 'A man is standing next to a car.',
#  '000000124800': 'A large clock tower with a clock on top of it.',
#  '000000124836': 'A plate of food with a fork and a fork.',
#  '000000124903': 'A man is riding a horse on a dirt road.',
#  '000000125348': 'A train is on a track near a building.',
#  '000000125351': 'A man in a blue shirt is standing on a sidewalk.',
#  '000000125662': 'A train is parked on the tracks in a rural area.',
#  '000000125672': 'A group of people playing frisbee on a field.',
#  '000000125683': 'A cat sitting on top of a wooden table.',
#  '000000125729': 'A large plane is on a runway in the water.',
#  '000000126263': 'A man is standing next to a dog.',
#  '000000126345': 'A brown dog is running in the grass.',
#  '000000126540': 'A large bathroom with a toilet and a sink.',
#  '000000127119': 'A group of people playing frisbee on a field.',
#  '000000127657': 'A man in a black shirt is holding a cell phone.',
#  '000000127926': 'A man in a black shirt is holding a cell phone.',
#  '000000128695': 'A bathroom with a toilet and a sink sink.',
#  '000000128826': 'A table with a laptop and a laptop on it.',
#  '000000130011': 'A man in a white shirt is standing in front of a building.',
#  '000000130973': 'A large jetliner sitting on top of a runway.',
#  '000000131127': 'A group of people standing in front of a building.',
#  '000000131696': 'A man is riding a horse on a dirt road.',
#  '000000132654': 'A large clock is on a pole in a field.',
#  '000000133660': 'A man in a black shirt is riding a skateboard.',
#  '000000135356': 'A man is standing in front of a window.',
#  '000000135978': 'A man is riding a horse on a dirt road.',
#  '000000136154': 'A large building with a clock on the top of it.',
#  '000000136181': 'A bathroom with a toilet and a sink sink.',
#  '000000136572': 'A man in a blue shirt is riding a skateboard.',
#  '000000136962': 'A plate of food with a fork and a fork.',
#  '000000137490': 'A large airplane flying over a large body of water.',
#  '000000137507': 'A plate of food and a fork on a table.',
#  '000000137573': 'A man is standing next to a dog.',
#  '000000137836': 'A giraffe standing next to a tree in a field.',
#  '000000138022': 'A red and white train is on a track.',
#  '000000138185': 'A man in a blue shirt is holding a baseball bat.',
#  '000000138514': 'A man is riding a wave on a skateboard.',
#  '000000139040': 'A man in a blue shirt is holding a cell phone.',
#  '000000139734': 'A plate with a fork and a fork on it.',
#  '000000140065': 'A young girl is playing with a frisbee in a field.',
#  '000000140197': 'A man in a blue shirt is holding a tennis racket.',
#  '000000140758': 'A man is standing on a beach with a surfboard.',
#  '000000141207': 'A group of people standing on top of a beach.',
#  '000000141240': 'A cat sitting on top of a wooden table.',
#  '000000141426': 'A group of people standing next to a tree.',
#  '000000141922': 'A man in a black shirt and a black shirt is holding a cell phone.',
#  '000000141923': 'A man is riding a horse on a dirt road.',
#  '000000142825': 'A man in a black shirt is playing with a frisbee.',
#  '000000143098': 'A baseball player is swinging a bat at a ball.',
#  '000000143192': 'A man is riding a horse on a field.',
#  '000000143263': 'A person on skis in the snow with a snowboard.',
#  '000000143553': 'A man in a white shirt is standing in front of a building.',
#  '000000143569': 'A train is parked on the tracks in front of a building.',
#  '000000143696': 'A group of people standing on a bench in a field.',
#  '000000144088': 'A cat sitting on top of a wooden table.',
#  '000000144620': 'A man in a blue shirt is standing in front of a tree.',
#  '000000144734': 'A red and white train is on a track.',
#  '000000144884': 'A white vase with a red and white flowers.',
#  '000000145391': 'A bunch of bananas are sitting on a table.',
#  '000000146640': 'A woman in a red shirt is holding a plate of food.',
#  '000000146656': 'A man is riding a motorcycle down a street.',
#  '000000146675': 'A group of people playing tennis on a tennis court.',
#  '000000146773': 'A small girl is eating a piece of cake.',
#  '000000147904': 'A group of people flying kites in the sand.',
#  '000000148614': 'A bathroom with a toilet and a sink sink.',
#  '000000148924': 'A baseball player is swinging a bat at a ball.',
#  '000000149228': 'A man is riding a wave on a surfboard.',
#  '000000149572': 'A man in a blue shirt is holding a tennis racket.',
#  '000000150616': 'A bathroom with a toilet and a sink sink.',
#  '000000151432': 'A large plane flying over a body of water.',
#  '000000154307': 'A cat sitting on top of a wooden bench.',
#  '000000154888': 'A man in a white shirt is standing in front of a building.',
#  '000000154955': 'A cat sitting on top of a wooden table.',
#  '000000156202': 'A man in a blue shirt is holding a plate of food.',
#  '000000156282': 'A large airplane flying over a large body of water.',
#  '000000156532': 'A large airplane flying over a large body of water.',
#  '000000157238': 'A cat is sitting on a bed in front of a laptop.',
#  '000000157301': 'A man is standing in front of a car.',
#  '000000157519': 'A man in a black shirt is standing on a sidewalk.',
#  '000000158588': 'A group of people standing in front of a building.',
#  '000000158737': 'A man in a blue shirt is playing with a frisbee.',
#  '000000159038': 'A small bird sitting on top of a wooden table.',
#  '000000159151': 'A kitchen with a sink and a sink.',
#  '000000160014': 'A kitchen with a sink and a sink.',
#  '000000160137': 'A cat sitting on top of a wooden table.',
#  '000000160509': 'A man in a white shirt is playing a video game.',
#  '000000160886': 'A plate of food and a fork on a table.',
#  '000000161121': 'A bunch of bananas are sitting on a table.',
#  '000000161539': 'A large building with a clock on it is shown.',
#  '000000161940': 'A woman in a blue shirt is holding a plate of food.',
#  '000000162087': 'A fire hydrant is on the side of a street.',
#  '000000162285': 'A plate of food with a fork and a fork.',
#  '000000162855': 'A man is playing frisbee on a field.',
#  '000000162880': 'A plate of food and a fork on a table.',
#  '000000163192': 'A close up of a cat on a bed with a fork in it.',
#  '000000163309': 'A close up of a plate of food on a table.',
#  '000000163361': 'A small airplane flying in the sky near a blue sky.',
#  '000000163460': 'A man in a black shirt is holding a cell phone.',
#  '000000164594': 'A herd of elephants walking across a dirt road.',
#  '000000164810': 'A man is standing on a skateboard in the middle of a street.',
#  '000000164899': 'A group of people sitting at a table with a large pizza.',
#  '000000165064': 'A man in a red shirt is holding a tennis racket.',
#  '000000165547': 'A kitchen with a sink and a sink.',
#  '000000166018': 'A living room with a couch and a table.',
#  '000000166047': 'A man is playing tennis on a tennis court.',
#  '000000166297': 'A man in a white shirt is standing on a bench.',
#  '000000166349': 'A man riding a wave on a surfboard in the ocean.',
#  '000000166653': 'A parking meter with a red and white seat on the side of it.',
#  '000000167115': 'A man in a red shirt is holding a sandwich.',
#  '000000168349': 'A man in a black shirt is holding a cell phone.',
#  '000000168618': 'A large bird sitting on top of a branch.',
#  '000000168692': 'A group of people standing on a beach with a dog.',
#  '000000168775': 'A man in a black shirt and a black shirt is holding a plate of food.',
#  '000000168805': 'A large clock tower with a clock on the top of it.',
#  '000000168898': 'A plate of food with a fork and a fork.',
#  '000000169448': 'A red and white train is on a track.',
#  '000000169660': 'A cat sitting on top of a wooden bench.',
#  '000000169683': 'A large bird is sitting on a rock.',
#  '000000169872': 'A train is parked on the tracks in front of a building.',
#  '000000170562': 'A group of people standing on a bench.',
#  '000000170662': 'A train is on a track near a forest.',
#  '000000170980': 'A small vase with a red and white and red and white and red and white and white and white and white and a knife.',
#  '000000171201': 'A man in a black shirt and a black shirt is holding a cell phone.',
#  '000000171353': 'A train is parked on the tracks in a city.',
#  '000000171536': 'A man in a blue shirt is playing a guitar.',
#  '000000172673': 'A large clock on a pole in a city.',
#  '000000172886': 'A bathroom with a toilet and a sink in it.',
#  '000000173997': 'A red and white train is on a track.',
#  '000000174496': 'A plate of food on a table with a fork.',
#  '000000175136': 'A man in a blue shirt is standing next to a fire hydrant.',
#  '000000175142': 'A man is standing next to a tree.',
#  '000000175180': 'A man is flying a kite on a beach.',
#  '000000175318': 'A train is parked on the tracks in front of a building.',
#  '000000175946': 'A man in a white shirt is standing in front of a store.',
#  '000000176192': 'A cat laying on top of a bed.',
#  '000000176285': 'A man is riding a horse on a dirt road.',
#  '000000176392': 'A man in a white shirt is playing a guitar.',
#  '000000176527': 'A man in a black shirt is standing on a surfboard.',
#  '000000176871': 'A large clock on a pole in a field.',
#  '000000177173': 'A red and white train is on a track.',
#  '000000177990': 'A group of people playing frisbee on a field.',
#  '000000178178': 'A large bathroom with a toilet and a sink.',
#  '000000178198': 'A man in a blue shirt is playing a guitar with a woman.',
#  '000000178361': 'A surfer is riding a wave in the ocean.',
#  '000000178748': 'A plate of food with a fork and a fork.',
#  '000000178849': 'A large group of people standing on a sidewalk.',
#  '000000179687': 'A man is standing on a skateboard in the snow.',
#  '000000179758': 'A man is playing frisbee in a field.',
#  '000000180123': 'A plate of food with a fork and a fork.',
#  '000000180186': 'A plate of food with a fork and a fork.',
#  '000000180350': 'A group of people standing on a sidewalk in front of a building.',
#  '000000180470': 'A man in a blue shirt is standing next to a tree.',
#  '000000181330': 'A red fire hydrant sitting on the side of a road.',
#  '000000181403': 'A small clock on a pole in a room.',
#  '000000181519': 'A bathroom with a toilet and toilet in the corner.',
#  '000000181711': 'A man is walking down the street with a large blue umbrella.',
#  '000000181850': 'A man in a blue shirt is holding a plate of food.',
#  '000000181941': 'A man is skiing down a snow covered slope.',
#  '000000182295': 'A living room with a couch and a table.',
#  '000000182416': 'A man in a black shirt is riding a skateboard.',
#  '000000182658': 'A cat is sitting on a bed in a bathroom.',
#  '000000182706': 'A man in a blue shirt is standing next to a fire hydrant.',
#  '000000182736': 'A train is on a track near a forest.',
#  '000000183785': 'A pizza with a fork and a fork on top of it.',
#  '000000184282': 'A red and white train is on a track.',
#  '000000184355': 'A train is on the tracks in the middle of a city.',
#  '000000184397': 'A group of people standing on a sidewalk with a dog.',
#  '000000185360': 'A large clock tower with a clock on top of it.',
#  '000000187262': 'A bathroom with a toilet and a sink.',
#  '000000187279': 'A cat sitting on top of a wooden table.',
#  '000000187397': 'A white plate topped with a fork and a fork.',
#  '000000188599': 'A man is standing in front of a building.',
#  '000000189153': 'A group of people standing on top of a bench.',
#  '000000189295': 'A large airplane is on a runway in the water.',
#  '000000189351': 'A man is riding a skateboard on a ramp.',
#  '000000189600': 'A plate of food on a table with a fork.',
#  '000000189694': 'A man in a black shirt and a black shirt is holding a cell phone.',
#  '000000190297': 'A woman in a blue shirt is holding a cell phone.',
#  '000000190334': 'A man in a white shirt is standing next to a fire hydrant.',
#  '000000190406': 'A train is parked on the tracks in the middle of a city.',
#  '000000191078': 'A plate of food with a fork and a fork.',
#  '000000191648': 'A man is riding a horse on a beach.',
#  '000000191893': 'A large clock tower with a clock on the top.',
#  '000000192079': 'A man in a blue shirt is holding a plate of food.',
#  '000000192233': 'A tennis player is swinging his racket at a ball.',
#  '000000192394': 'A man is standing on a beach with a surfboard.',
#  '000000192866': 'A red and white train is on a track.',
#  '000000193594': 'A man in a white shirt is holding a baby.',
#  '000000195267': 'A man is riding a horse on a dirt road.',
#  '000000195433': 'A small bird sitting on top of a white table.',
#  '000000196379': 'A man in a blue shirt is standing on a sidewalk.',
#  '000000196777': 'A large plane is on a runway in the water.',
#  '000000196842': 'A man is riding a motorcycle down a street.',
#  '000000197408': 'A small clock sitting on top of a table.',
#  '000000198289': 'A woman in a red shirt is holding a tennis racket.',
#  '000000198426': 'A man in a white shirt is standing next to a fire hydrant.',
#  '000000198495': 'A train is parked on the tracks in front of a building.',
#  '000000198704': 'A large clock on a pole in a city.',
#  '000000199244': 'A man in a blue shirt is standing next to a fire hydrant.',
#  '000000199268': 'A group of people sitting at a table with a cake.',
#  '000000199819': 'A little girl is eating a slice of cake.',
#  '000000200612': 'A large white jet is on a runway.',
#  '000000200681': 'A man is standing on a bench in the grass.',
#  '000000200727': 'A group of elephants walking in a field.',
#  '000000201220': 'A man in a black shirt and a black shirt is holding a baby.',
#  '000000201402': 'A man in a white shirt is standing in front of a building.',
#  '000000201492': 'A large clock on a pole in a field.',
#  '000000201859': 'A train is parked on the tracks in front of a building.',
#  '000000201939': 'A man in a blue shirt is standing next to a fire hydrant.',
#  '000000202617': 'A red and white train is on a track.',
#  '000000203618': 'A table with a bowl of food and a drink.',
#  '000000204041': 'A person is surfing in the air on a surfboard.',
#  '000000204603': 'A man is standing on a bench in the middle of a river.',
#  '000000204777': 'A woman in a blue shirt is holding a plate of food.',
#  '000000205126': 'A plate of food with a salad and a fork.',
#  '000000205672': 'A man is standing next to a dog.',
#  '000000205689': 'A man in a black shirt and tie is holding a cell phone.',
#  '000000205757': 'A plate of food with a fork and a fork.',
#  '000000206587': 'A group of people standing on top of a lush green field.',
#  '000000206622': 'A man is standing next to a horse.',
#  '000000206731': 'A fire hydrant is on a city street.',
#  '000000207142': 'A small bird sitting on top of a white table.',
#  '000000207458': 'A man is riding a skateboard on a dirt road.',
#  '000000207992': 'A group of people standing on top of a beach.',
#  '000000208319': 'A red and white fire hydrant in a field.',
#  '000000208779': 'A cat is laying on top of a wooden bench.',
#  '000000209128': 'A man in a blue shirt is holding a baseball bat.',
#  '000000209292': 'A large clock on a pole in a room.',
#  '000000209531': 'A man is standing on a skateboard in the snow.',
#  '000000210567': 'A man is standing on a tennis court.',
#  '000000210686': 'A large clock tower with a clock on top of it.',
#  '000000210766': 'A red and white train is on a track.',
#  '000000211158': 'A black and white photo of a man in a black shirt and a black shirt is standing on a horse.',
#  '000000211302': 'A computer desk with a computer on it and a laptop computer.',
#  '000000212321': 'A kitchen with a couch and a table.',
#  '000000212824': 'A red bus is parked on the side of a street.',
#  '000000212846': 'A herd of sheep standing in a field of grass.',
#  '000000213023': 'A giraffe standing in a field with a tree in the background.',
#  '000000213537': 'A group of people standing on a bench in front of a building.',
#  '000000213646': 'A herd of sheep standing in a field of grass.',
#  '000000213799': 'A cat sitting on top of a wooden table.',
#  '000000214326': 'A man in a black shirt is holding a baseball bat.',
#  '000000214475': 'A plate of food with a fork and a fork.',
#  '000000214742': 'A man is standing next to a truck.',
#  '000000215024': 'A group of people standing on top of a beach.',
#  '000000215107': 'A man in a red shirt is riding a skateboard.',
#  '000000215303': 'A man in a black shirt is standing next to a tree.',
#  '000000215549': 'A train is on a track near a building.',
#  '000000216206': 'A plate of food and a fork on a table.',
#  '000000216303': 'A man in a blue shirt is holding a tennis racket.',
#  '000000216820': 'A plate of food with a fork and a fork.',
#  '000000217393': 'A man in a black shirt is riding a horse.',
#  '000000217495': 'A woman in a blue shirt is holding a baby.',
#  '000000217561': 'A man is riding a skateboard on a ramp.',
#  '000000218964': 'A pizza with a fork and a fork on top of it.',
#  '000000219196': 'A giraffe standing next to a tree in a field.',
#  '000000219502': 'A woman in a blue shirt is holding a plate of food.',
#  '000000219546': 'A table with a sandwich and a drink on it.',
#  '000000222866': 'A plate of food with a salad and a fork.',
#  '000000223616': 'A group of people standing on a bench.',
#  '000000223857': 'A woman in a suit and tie is holding a cell phone.',
#  '000000224037': 'A man is standing next to a tree.',
#  '000000224166': 'A man in a blue shirt is playing a guitar with a large child.',
#  '000000224247': 'A large plane is flying over a body of water.',
#  '000000224541': 'A man in a black shirt and a black shirt is holding a plate of food.',
#  '000000225053': 'A man in a blue shirt is playing with a frisbee.',
#  '000000226536': 'A cat sitting on top of a wooden table.',
#  '000000226550': 'A white vase with a red and white flowers.',
#  '000000226874': 'A pizza with a fork and a fork on top of it.',
#  '000000227851': 'A woman in a blue shirt is playing a guitar.',
#  '000000228419': 'A plate of food with a fork and a fork on it.',
#  '000000228657': 'A group of people standing on top of a beach with a kite.',
#  '000000229149': 'A group of people standing in front of a building.',
#  '000000229707': 'A man in a black shirt and tie is holding a cell phone.',
#  '000000230038': 'A plate of food on a table with a fork.',
#  '000000230503': 'A man in a blue shirt is riding a skateboard.',
#  '000000231500': 'A living room with a couch and a table.',
#  '000000231667': 'A man in a black shirt is riding a white surfboard.',
#  '000000232049': 'A baseball player is swinging a bat at a ball.',
#  '000000232076': 'A large building with a clock on it.',
#  '000000232627': 'A bird sitting on a branch in a bowl.',
#  '000000233384': 'A red and white train is on a track.',
#  '000000233926': 'A man is standing on a sidewalk with a dog.',
#  '000000234749': 'A plate of food with a fork and a fork.',
#  '000000235132': 'A group of people standing on top of a beach flying a kite.',
#  '000000236155': 'A woman in a red shirt is holding a cell phone.',
#  '000000237394': 'A large airplane flying over a large body of water.',
#  '000000237762': 'A plate of food and a fork on a table.',
#  '000000238114': 'A red and white train is on a track.',
#  '000000238602': 'A cat laying on top of a wooden chair.',
#  '000000239580': 'A large clock on a pole in a city.',
#  '000000239801': 'A plate of food with a fork and a fork on it.',
#  '000000240449': 'A person on skis on a snowy slope.',
#  '000000240655': 'A man is riding a skateboard on a snowy hill.',
#  '000000240889': 'A man in a white shirt is standing in front of a store.',
#  '000000241025': 'A large airplane flying over a body of water.',
#  '000000241068': 'A cat is sitting on a wooden desk.',
#  '000000241790': 'A large airplane flying over a blue sky.',
#  '000000241821': 'A bathroom with a toilet and a sink sink.',
#  '000000241860': 'A living room with a couch and a table.',
#  '000000241918': 'A man in a black jacket is riding a snowboard.',
#  '000000242029': 'A train is parked on the tracks in front of a building.',
#  '000000242325': 'A man is riding a horse on a dirt road.',
#  '000000243153': 'A man in a blue shirt is holding a baseball bat.',
#  '000000243173': 'A man is standing next to a building.',
#  '000000243324': 'A group of elephants walking in the water.',
#  '000000243384': 'A large clock tower with a clock on top of it.',
#  '000000243845': 'A man in a black shirt is riding a skateboard.',
#  '000000244293': 'A red and white bus is parked on the side of a street.',
#  '000000244349': 'A red and white bus is parked on the side of a street.',
#  '000000244540': 'A group of people standing on top of a beach.',
#  '000000244582': 'A black dog is standing on a rock.',
#  '000000244735': 'A group of people sitting at a table with a large glass of wine.',
#  '000000247157': 'A kitchen with a sink and a sink.',
#  '000000247394': 'A person is flying a kite in the water.',
#  '000000248009': 'A toilet with a toilet and a sink in it.',
#  '000000248133': 'A large clock on a pole in a field.',
#  '000000248391': 'A man in a black shirt is holding a baseball bat.',
#  '000000248956': 'A man in a blue shirt is standing on a sidewalk.',
#  '000000249720': 'A group of people standing on a sidewalk with a dog.',
#  '000000251044': 'A man in a white shirt is standing in front of a building.',
#  '000000251835': 'A red fire hydrant sitting in a grassy area.',
#  '000000251932': 'A person is flying a kite on a beach.',
#  '000000252280': 'A train is traveling down the tracks in the middle of a city.',
#  '000000252617': 'A cat is sitting on a wooden bench.',
#  '000000253419': 'A large airplane flying over a blue sky.',
#  '000000253474': 'A group of people standing on a snow covered slope.',
#  '000000253825': 'A small vase with a red and white flowers.',
#  '000000253971': 'A group of people standing on top of a beach.',
#  '000000254198': 'A train is parked on the tracks in front of a building.',
#  '000000254729': 'A large airplane flying over a large body of water.',
#  '000000254778': 'A large clock on a pole in a field.',
#  '000000254929': 'A pizza with a fork and a fork on top of it.',
#  '000000255069': 'A man in a black shirt is standing next to a tree.',
#  '000000255295': 'A cat sitting on top of a wooden table.',
#  '000000255315': 'A man is standing in front of a car.',
#  '000000256465': 'A man in a white shirt is standing in front of a building.',
#  '000000256664': 'A plate of food with a fork and a fork.',
#  '000000257301': 'A man in a black shirt is standing next to a giraffe.',
#  '000000257864': 'A table with a sandwich and a fork on it.',
#  '000000258129': 'A group of people playing frisbee on a field.',
#  '000000259591': 'A man is standing next to a dog.',
#  '000000259879': 'A cat is sitting on a rock in the water.',
#  '000000260034': 'A large building with a clock on it is shown.',
#  '000000260099': 'A train is on a track near a forest.',
#  '000000260373': 'A man in a black shirt is standing next to a man in a red shirt.',
#  '000000261196': 'A pizza with a fork on top of it.',
#  '000000261225': 'A red fire hydrant sitting on top of a sidewalk.',
#  '000000264909': 'A man is standing on a surfboard in the water.',
#  '000000265938': 'A group of people standing in front of a building.',
#  '000000265971': 'A tennis player is holding a racket on a tennis court.',
#  '000000266041': 'A man in a black shirt is holding a cell phone.',
#  '000000266298': 'A man riding a wave on a surfboard in the ocean.',
#  '000000266437': 'A group of people on a beach playing a game.',
#  '000000266486': 'A man in a white shirt is standing in front of a building.',
#  '000000266853': 'A dog is laying on a bed.',
#  '000000267205': 'A large jetliner sitting on top of a runway.',
#  '000000267242': 'A group of giraffes standing in a field.',
#  '000000267417': 'A young girl is playing with a frisbee in a field.',
#  '000000267802': 'A large group of people standing in front of a building.',
#  '000000267840': 'A fire hydrant in front of a building.',
#  '000000268036': 'A man is riding a horse on a street.',
#  '000000268058': 'A woman in a red shirt is holding a plate of food.',
#  '000000268640': 'A man in a black shirt is holding a cell phone.',
#  '000000269327': 'A red and white train traveling on a track.',
#  '000000269431': 'A man in a white shirt is standing in front of a window.',
#  '000000269543': 'A group of people standing in front of a building.',
#  '000000269958': 'A man is standing next to a man in a white shirt and a woman in a white shirt.',
#  '000000270959': 'A train is parked on the tracks in front of a building.',
#  '000000271373': 'A man in a red jacket is skiing down a snow covered slope.',
#  '000000272357': 'A tennis player is swinging a racket at a ball.',
#  '000000272785': 'A table with a sandwich and a fork on it.',
#  '000000273196': 'A large clock on a pole in a city.',
#  '000000274591': 'A black dog is running in a field.',
#  '000000274632': 'A kitchen with a sink and a sink.',
#  '000000275117': 'A man in a black shirt and tie is holding a cell phone.',
#  '000000275658': 'A red and white train is on a track.',
#  '000000275744': 'A train is parked on the tracks in front of a building.',
#  '000000277503': 'A man is standing on a beach with a kite.',
#  '000000278287': 'A white polar bear is standing on a beach.',
#  '000000278335': 'A train is parked on the tracks in front of a building.',
#  '000000279104': 'A close up of a plate of food on a table.',
#  '000000279806': 'A person is skiing down a snow covered slope.',
#  '000000280023': 'A group of people sitting around a table.',
#  '000000280158': 'A man in a red jacket is riding a snowboard.',
#  '000000280220': 'A man in a black shirt and tie is standing in a field.',
#  '000000280249': 'A bird is sitting on top of a beach.',
#  '000000281293': 'A man in a blue shirt is holding a tennis racket.',
#  '000000281301': 'A group of people standing on top of a beach.',
#  '000000281676': 'A group of people riding horses on a street.',
#  '000000281855': 'A man riding a wave on a surfboard in the ocean.',
#  '000000282667': 'A woman in a blue shirt is holding a large banana.',
#  '000000282841': 'A cat sitting on top of a wooden table.',
#  '000000283382': 'A bathroom with a toilet and a sink sink.',
#  '000000284144': 'A clock on a pole in front of a building.',
#  '000000284722': 'A man in a blue shirt is standing on a sidewalk.',
#  '000000285018': 'A bathroom with a toilet and a sink in it.',
#  '000000285093': 'A bird is perched on a branch in a field.',
#  '000000285250': 'A man is flying a kite on a beach.',
#  '000000285734': 'A man is playing tennis on a field.',
#  '000000285893': 'A man in a black shirt is holding a baseball bat.',
#  '000000285910': 'A kitchen with a sink and a sink.',
#  '000000286106': 'A man in a blue shirt is holding a plate of food.',
#  '000000286176': 'A man is standing next to a building.',
#  '000000286673': 'A pizza sitting on top of a white plate.',
#  '000000287006': 'A pizza with a fork and a fork on top of it.',
#  '000000287830': 'A large airplane flying over a blue sky.',
#  '000000287846': 'A man in a black shirt is jumping in the ocean.',
#  '000000287886': 'A bathroom with a toilet and a sink sink.',
#  '000000288650': 'A stop sign with a clock on the side of it.',
#  '000000288770': 'A man is standing next to a car.',
#  '000000289204': 'A man is standing on a sidewalk with a large blue umbrella.',
#  '000000289263': 'A young boy in a wet suit is jumping into the water.',
#  '000000289621': 'A man in a black shirt is standing next to a woman in a red shirt.',
#  '000000289941': 'A man in a black shirt and a tie is holding a cell phone.',
#  '000000290110': 'A red bus is parked on the side of a street.',
#  '000000290724': 'A train is parked on the tracks in front of a building.',
#  '000000291098': 'A man in a blue shirt is holding a baseball bat.',
#  '000000291144': 'A man is standing in front of a car.',
#  '000000291321': 'A small bird sitting on top of a white table.',
#  '000000291889': 'A man is standing next to a tree.',
#  '000000292844': 'A man in a white shirt is standing in front of a building.',
#  '000000293233': 'A baseball player is swinging a bat at a ball.',
#  '000000293304': 'A kitchen with a sink and a sink.',
#  '000000293453': 'A man in a white shirt is standing in front of a building.',
#  '000000293799': 'A large airplane flying over a large body of water.',
#  '000000294973': 'A man in a blue shirt is standing next to a fire hydrant.',
#  '000000295257': 'A group of people playing frisbee in a field.',
#  '000000295476': 'A man in a red jacket is riding a skateboard.',
#  '000000295642': 'A large clock tower with a clock on the top of it.',
#  '000000296696': 'A person is holding a banana in a bowl.',
#  '000000296782': 'A train is traveling down the tracks in a city.',
#  '000000296871': 'A man in a black shirt is standing next to a dog.',
#  '000000296943': 'A train is on a track near a bridge.',
#  '000000297200': 'A group of people standing on top of a beach.',
#  '000000297414': 'A red and white train is on a track.',
# ...
#  '000000304355': 'A bathroom with a toilet and a sink in the corner.',
#  '000000304584': 'A group of people standing in front of a building.',
#  '000000305267': 'A woman eating a slice of pizza on a plate.',
#  '000000305451': 'A man in a black shirt and a black shirt is holding a plate of food.',
#  '000000306313': 'A red and white train is on a track.',
#  '000000306627': 'A man in a black shirt and a black shirt is holding a plate of food.',
#  '000000307020': 'A large elephant is standing in the water.',
#  '000000307048': 'A man is standing next to a dog.',
#  '000000307989': 'A cat is sitting on a bed in a bathroom.',
#  '000000308405': 'A large clock tower with a clock on top of it.',
#  '000000308687': 'A woman in a red shirt is holding a plate of food.',
#  '000000308766': 'A woman in a red shirt is holding a tennis racket.',
#  '000000308825': 'A laptop computer on a desk with a mouse on it.',
#  '000000308838': 'A man is skiing down a snow covered slope.',
#  '000000309100': 'A zebra is standing in the grass near a tree.',
#  '000000309222': 'A man is riding a skateboard on a ramp.',
#  '000000310085': 'A large airplane flying over a body of water.',
#  '000000310136': 'A baseball player is swinging a bat at a ball.',
#  '000000310558': 'A man in a black shirt is standing next to a woman in a red shirt.',
#  '000000310757': 'A cat laying on top of a bed.',
#  '000000311475': 'A large airplane is on a runway in the water.',
#  '000000311773': 'A woman in a white shirt and tie is holding a cell phone.',
#  '000000311904': 'A woman in a blue shirt is holding a cell phone.',
#  '000000312220': 'A dog is running in the grass.',
#  '000000312282': 'A plate of food with a fork and a fork.',
#  '000000312446': 'A brown dog is standing in the grass.',
#  '000000313113': 'A plate of food on a table with a fork.',
#  '000000313280': 'A group of people standing on a sidewalk with a large umbrella.',
#  '000000313345': 'A man is standing on a snow covered slope.',
#  '000000313609': 'A man in a white shirt is playing a guitar with a dog.',
#  '000000314788': 'A large plane is on a runway in the water.',
#  '000000315013': 'A bathroom with a toilet and a sink in the corner.',
#  '000000315474': 'A train is on a track near a building.',
#  '000000316336': 'A large clock on a pole in a room.',
#  '000000317896': 'A woman is eating a pizza on a table.',
#  '000000318736': 'A living room with a couch and a table.',
#  '000000318825': 'A tennis player is holding a racket on a tennis court.',
#  '000000319121': 'A large clock on a pole in a city.',
#  '000000319690': 'A man in a blue shirt is holding a cell phone.',
#  '000000319781': 'A woman in a suit and tie is holding a cell phone.',
#  '000000320039': 'A woman in a blue shirt is holding a baby.',
#  '000000320203': 'A red and white plane flying in the sky.',
#  '000000320429': 'A group of people standing on a beach with a large kite.',
#  '000000321196': 'A large airplane flying over a body of water.',
#  '000000321603': 'A kitchen with a sink and a sink.',
#  '000000321679': 'A red and white bus is parked on the street.',
#  '000000322630': 'A brown dog is running in the grass.',
#  '000000322769': 'A bathroom with a toilet and a sink sink.',
#  '000000323462': 'A bathroom with a toilet and a sink.',
#  '000000323612': 'A living room with a couch and a table.',
#  '000000323790': 'A pizza with a fork on top of it on top of it.',
#  '000000323964': 'A woman is eating a hot dog on a plate.',
#  '000000324413': 'A train is parked on the tracks in front of a building.',
#  '000000324455': 'A bird is flying over a body of water.',
#  '000000324710': 'A man in a black shirt is riding a horse.',
#  '000000325079': 'A man in a white shirt is standing next to a woman in a red shirt.',
#  '000000325287': 'A man in a white shirt is playing a guitar with a woman.',
#  '000000325955': 'A man is walking down the street with a large red umbrella.',
#  '000000326021': 'A woman in a blue shirt is playing with a frisbee.',
#  '000000326496': 'A man in a red shirt is holding a baseball bat.',
#  '000000326555': 'A man is standing on a beach holding a surfboard.',
#  '000000326592': 'A man is riding a horse on a beach.',
#  '000000326853': 'A man in a white shirt is standing in front of a window.',
#  '000000327063': 'A group of people standing on a beach with a dog.',
#  '000000327271': 'A large airplane is on a runway in the water.',
#  '000000329133': 'A large clock on a pole in a city.',
#  '000000329175': 'A large clock on a pole in a city.',
#  '000000329797': 'A white jet is sitting on the runway.',
#  '000000329806': 'A large clock tower with a clock on top of it.',
#  '000000330356': 'A group of people standing on top of a beach flying a kite.',
#  '000000330400': 'A large airplane is flying over a body of water.',
#  '000000330419': 'A group of zebras standing in a field.',
#  '000000330916': 'A bathroom with a toilet and a sink.',
#  '000000331223': 'A man in a blue shirt is holding a baseball bat.',
#  '000000331314': 'A table with a sandwich and a fork on it.',
#  '000000331544': 'A man in a white shirt is playing a guitar with a woman.',
#  '000000331907': 'A herd of sheep standing in a field of grass.',
#  '000000332074': 'A group of people standing on a beach with a large kite.',
#  '000000332271': 'A train is parked on the tracks in the city.',
#  '000000332623': 'A man in a blue shirt is standing on a beach.',
#  '000000333156': 'A man in a blue shirt is holding a plate of food.',
#  '000000333621': 'A table with a laptop and a laptop on it.',
#  '000000333704': 'A man in a suit is holding a cell phone.',
#  '000000334939': 'A plate of food with a salad and a fork.',
#  '000000335967': 'A cat sitting on top of a wooden desk.',
#  '000000336015': 'A person on a snowboard on a snowy slope.',
#  '000000336937': 'A large clock on a pole in a field.',
#  '000000338579': 'A group of people standing on top of a hill in the woods.',
#  '000000339019': 'A group of people standing on top of a beach.',
#  '000000339031': 'A large clock tower with a clock on it.',
#  '000000339307': 'A tennis player is swinging his racket at a tennis ball.',
#  '000000339687': 'A man in a black shirt is standing next to a woman in a red shirt.',
#  '000000339815': 'A plate of food with a fork and a fork on it.',
#  '000000340181': 'A man in a black shirt and tie is holding a baseball bat.',
#  '000000340285': 'A baseball player is swinging a bat at a ball.',
#  '000000341219': 'A woman in a white shirt and a white shirt is holding a plate of food.',
#  '000000341639': 'A bird is sitting on top of a rock.',
#  '000000341736': 'A man is standing on a sidewalk with a large red umbrella.',
#  '000000342060': 'A man in a blue shirt is standing on a bench.',
#  '000000342387': 'A man in a blue shirt is playing a guitar.',
#  '000000343503': 'A red fire hydrant sitting on the side of a street.',
#  '000000344025': 'A pizza sitting on top of a table.',
#  '000000344368': 'A cat is sitting on a wooden bench.',
#  '000000344521': 'A plate of food with a salad and a fork.',
#  '000000344765': 'A bathroom with a toilet and a sink sink.',
#  '000000345160': 'A woman in a blue shirt is playing a guitar.',
#  '000000345590': 'A herd of sheep grazing in a field.',
#  '000000346041': 'A large plane flying over a large body of water.',
#  '000000346160': 'A kitchen with a sink and a sink.',
#  '000000346702': 'A bathroom with a toilet and a sink sink.',
#  '000000347131': 'A table with a sandwich and a fork on it.',
#  '000000347235': 'A train is on a track near a forest.',
#  '000000347267': 'A young boy is playing with a frisbee in the air.',
#  '000000347648': 'A woman in a blue shirt is holding a plate of food.',
#  '000000348504': 'A person is flying a kite on a beach.',
#  '000000349552': 'A group of people riding skis on a snow covered slope.',
#  '000000349566': 'A herd of sheep standing on a beach.',
#  '000000349590': 'A man in a black shirt and a black shirt is holding a plate of food.',
#  '000000349896': 'A large herd of sheep standing on a lush green field.',
#  '000000350491': 'A bird is sitting on a rock in the water.',
#  '000000350549': 'A white toilet with a blue sky on top of it.',
#  '000000350966': 'A man in a blue shirt is standing next to a fire hydrant.',
#  '000000351013': 'A large airplane is on a runway in the water.',
#  '000000351141': 'A man in a blue shirt is holding a baseball bat.',
#  '000000351288': 'A group of people standing on top of a beach.',
#  '000000352041': 'A man is riding a skateboard on a ramp.',
#  '000000352129': 'A black and white dog is running on a dirt road.',
#  '000000352176': 'A plate of food on a table with a fork.',
#  '000000352476': 'A large building with a clock on it.',
#  '000000352735': 'A man in a red shirt is standing on a sidewalk.',
#  '000000353130': 'A plate of food with a salad and a fork.',
#  '000000353652': 'A group of people standing on top of a beach.',
#  '000000353836': 'A red fire hydrant sitting in a parking lot.',
#  '000000353937': 'A large clock on a pole in a city.',
#  '000000354027': 'A red train is parked on the tracks.',
#  '000000354368': 'A man is standing next to a horse.',
#  '000000354608': 'A large clock sitting on top of a pole.',
#  '000000354878': 'A man is riding a skateboard on a snow covered slope.',
#  '000000357089': 'A man in a blue shirt is holding a tennis racket.',
#  '000000357402': 'A tennis player is holding a tennis racket.',
#  '000000358247': 'A man in a blue shirt is standing in front of a building.',
#  '000000359141': 'A group of people playing frisbee on a field.',
#  '000000361253': 'A large clock on a pole in a city.',
#  '000000361376': 'A plate of food with a salad and a fork.',
#  '000000361519': 'A large airplane flying over a large body of water.',
#  '000000361638': 'A bathroom with a toilet and a sink in the corner.',
#  '000000361751': 'A man is riding a horse on a dirt road.',
#  '000000362198': 'A kitchen with a sink and a sink.',
#  '000000362811': 'A plate of food with a fork and a fork.',
#  '000000363880': 'A pizza sitting on top of a white plate.',
#  '000000365008': 'A group of zebras standing in a field.',
#  '000000365205': 'A cat is sitting on a wooden chair.',
#  '000000365631': 'A large clock tower with a clock on top of it.',
#  '000000365819': 'A cat sitting on top of a wooden table.',
#  '000000365833': 'A group of people standing on top of a beach.',
#  '000000366421': 'A large clock on a pole in a city.',
#  '000000366683': 'A table with a sandwich and a fork on it.',
#  '000000367881': 'A black and white photo of a dog and a dog of a baby elephant.',
#  '000000368040': 'A large clock tower with a clock on top of it.',
#  '000000368505': 'A large clock on a pole in a city.',
#  '000000368956': 'A group of people skiing down a snow covered slope.',
#  '000000369140': 'A group of people standing on top of a snow covered hill.',
#  '000000369568': 'A herd of sheep standing on a dirt road.',
#  '000000369598': 'A man riding a wave on a surfboard in the ocean.',
#  '000000369601': 'A cat sitting on top of a wooden table.',
#  '000000369969': 'A large plane flying over a large body of water.',
#  '000000370038': 'A man in a white shirt is playing a guitar with a man.',
#  '000000370095': 'A train is parked on the tracks in front of a building.',
#  '000000370399': 'A red fire hydrant sitting in a grassy area.',
#  '000000370729': 'A man in a black shirt and a black shirt is holding a cell phone.',
#  '000000370819': 'A bunch of bananas and vegetables on a table.',
#  '000000371092': 'A group of people sitting at a table with a cake.',
#  '000000371166': 'A man riding a wave on a surfboard in the ocean.',
#  '000000372660': 'A man in a black shirt and a black shirt is standing on a sidewalk.',
#  '000000373033': 'A large clock on a pole in a city.',
#  '000000373218': 'A giraffe standing next to a tree in a field.',
#  '000000373578': 'A zebra is standing in the grass near a tree.',
#  '000000373792': 'A large clock tower with a clock on the top.',
#  '000000373857': 'A living room with a couch and a table.',
#  '000000373923': 'A man in a blue shirt is riding a skateboard.',
#  '000000376362': 'A man in a wet suit is riding a wave.',
#  '000000376405': 'A living room with a couch and a couch with a window.',
#  '000000376410': 'A herd of sheep standing on a lush green field.',
#  '000000376422': 'A man in a white shirt is standing next to a fire hydrant.',
#  '000000377326': 'A man in a black shirt is riding a horse.',
#  '000000377911': 'A dog is laying on a rock in the grass.',
#  '000000378012': 'A large herd of cows standing in a field.',
#  '000000378311': 'A bathroom with a toilet and a sink.',
#  '000000378778': 'A baseball player is swinging a bat at a ball.',
#  '000000378823': 'A man in a black shirt is standing next to a tree.',
#  '000000379165': 'A woman is eating a hot dog on a bun.',
#  '000000379567': 'A bathroom with a toilet and a sink in the corner.',
#  '000000380128': 'A living room with a couch and a table.',
#  '000000380828': 'A man in a black shirt is standing next to a woman in a red shirt.',
#  '000000381037': 'A bathroom with a toilet and a sink sink.',
#  '000000381301': 'A train is parked on the tracks in a rural area.',
#  '000000381318': 'A pizza with a fork and a fork on it.',
#  '000000382171': 'A man is riding a horse on a dirt road.',
#  '000000382447': 'A large bathroom with a toilet and a sink.',
#  '000000382557': 'A group of people standing on a beach with a large blue umbrella.',
#  '000000382873': 'A man in a blue shirt is holding a tennis racket.',
#  '000000383209': 'A cat laying on top of a bed.',
#  '000000383329': 'A woman in a blue shirt is holding a cell phone.',
#  '000000383432': 'A red and white train traveling on a track.',
#  '000000383605': 'A baseball player is swinging a bat at a baseball game.',
#  '000000383760': 'A person riding a wave on a surfboard in the ocean.',
#  '000000383923': 'A man in a black shirt is standing next to a dog.',
#  '000000385485': 'A man in a black shirt is standing next to a dog.',
#  '000000385672': 'A red and white fire hydrant in a parking lot.',
#  '000000387105': 'A bird perched on a branch in a field.',
#  '000000387153': 'A large clock on a pole in a field.',
#  '000000387181': 'A woman in a suit and tie is holding a cell phone.',
#  '000000387506': 'A large airplane is on a runway in the water.',
#  '000000388417': 'A group of people standing on top of a beach.',
#  '000000388469': 'A small girl is eating a piece of cake.',
#  '000000388714': 'A person riding a wave on a surfboard.',
#  '000000389753': 'A large clock on a pole in a city.',
#  '000000390769': 'A red and white train is on a track.',
#  '000000390969': 'A man in a red shirt is standing on a street.',
#  '000000391496': 'A man in a black shirt is holding a cell phone.',
#  '000000391657': 'A large clock tower with a clock on top of it.',
#  '000000392105': 'A red and white train is on a track.',
#  '000000392315': 'A large airplane is flying over a body of water.',
#  '000000392723': 'A giraffe standing next to a tree in a field.',
#  '000000392914': 'A bathroom with a toilet and a toilet with a toilet and a toilet.',
#  '000000393108': 'A man in a suit and tie is holding a cell phone.',
#  '000000393258': 'A man in a black shirt and a black shirt is holding a cell phone.',
#  '000000393394': 'A white plate with a fork and a fork on top of it.',
#  '000000393480': 'A large group of people standing on a beach.',
#  '000000393777': 'A man in a blue shirt is standing in front of a building.',
#  '000000394132': 'A cat laying on top of a bed.',
#  '000000394322': 'A group of people standing next to a horse.',
#  '000000395096': 'A man in a blue shirt is standing next to a red and white car.',
#  '000000395678': 'A giraffe standing next to a tree in a field.',
#  '000000396167': 'A woman in a blue shirt is holding a baseball bat.',
#  '000000397658': 'A man is standing next to a dog.',
#  '000000397717': 'A large clock on a pole in a city.',
#  '000000397903': 'A man in a suit is holding a cell phone.',
#  '000000397950': 'A group of elephants walking in a river.',
#  '000000397980': 'A group of people playing frisbee on a field.',
#  '000000398729': 'A white toilet with a red seat on the top of it.',
#  '000000399241': 'A person surfing in the ocean.',
#  ...}

# %%
len(result_dict)
# Out:
# 1789
